# %% [markdown]
# <a href="https://colab.research.google.com/github/mullinskatie7-source/katherine-mullins.github.io/blob/main/Katherine_Mullins_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Markdown
# # Getting Started
#
# **Engineer:** Katherine Mullins
#
# **Completion Date:** 08/30/2026
#
# **Class:** EGN3443
#
# **Assignment #:** 1
#
# **Tool Used:** Colab / Python
#
# ## Problem Description
#
# The purpose of this assignment is to demonstrate readiness for future assignments by using Google Colab with Python and preparing the results in a formal report. A Python program must be created that displays the student's name, stores the values 6, 9, 4, 6, 5, 8, 6, and 7 in an array, calculates the average of those values, and displays the calculated average. The Colab notebook must also include a text block above the program containing the student's name.
#
# ## Methodology
#
# Google Colab was used to create and execute the Python program. A text cell was first placed above the program to identify the student. The numerical values provided in the assignment were then stored in a Python list. The average was determined by finding the sum of all values in the list and dividing that result by the number of values. The student's name and calculated average were displayed as output. After verifying that the program executed correctly, a screen capture was taken showing the text cell, Python code, and program output.

# %%
# Step 2: Average the array with my name
print("Katherine Mullins")

a = [6, 9, 4, 6, 5, 8, 6, 7]

average = sum(a) / len(a)

print("Average:", average)
# Out:
# Katherine Mullins
# Average: 6.375
